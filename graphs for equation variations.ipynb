# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Define dataset names
datasets = {
    "Original": {
        "adc vs adc": {
            "Champion": ["Aphelios", "Ashe", "Caitlyn", "Corki bot", "Ezreal", "Jhin", "Jinx", "Kai'Sa", "Kog'Maw", "Xayah"],
            "MinWinrate": [0.4193, 0.4112, 0.4418, 0.5029, 0.3564, 0.345, 0.4970, 0.3768, 0.4746, 0.4261]
        },
        "adc vs sup": {
            "Champion": ["Aphelios", "Ashe", "Caitlyn", "Corki bot", "Ezreal", "Jhin", "Jinx", "Kai'Sa", "Kog'Maw", "Xayah"],
            "MinWinrate": [0.3310, 0.4112, 0.4378, 0.5029, 0.3564, 0.345, 0.4970, 0.3321, 0.4430, 0.3488]
        },
        "adc 1v2": {
            "Champion": ["Aphelios", "Ashe", "Caitlyn", "Corki bot", "Ezreal", "Jhin", "Jinx", "Kai'Sa", "Kog'Maw", "Xayah"],
            "MinWinrate": [0.3389, 0.4112, 0.4378, 0.5029, 0.3564, 0.345, 0.4970, 0.3321, 0.4430, 0.3535]
        },
    },
    "Equation 1": {
        "adc vs adc": {
            "Champion": ["Aphelios", "Ashe", "Caitlyn", "Corki bot", "Ezreal", "Jhin", "Jinx", "Kai'Sa", "Kog'Maw", "Xayah"],
            "MinWinrate": [0.4300, 0.4652, 0.4530, 0.5180, 0.4392, 0.4284, 0.4819, 0.4297, 0.4675, 0.4473]
        },
        "adc vs sup": {
            "Champion": ["Aphelios", "Ashe", "Caitlyn", "Corki bot", "Ezreal", "Jhin", "Jinx", "Kai'Sa", "Kog'Maw", "Xayah"],
            "MinWinrate": [0.4155, 0.4646, 0.4530, 0.5180, 0.4392, 0.4284, 0.4819, 0.4085, 0.4609, 0.4272]
        },
        "adc 1v2": {
            "Champion": ["Aphelios", "Ashe", "Caitlyn", "Corki bot", "Ezreal", "Jhin", "Jinx", "Kai'Sa", "Kog'Maw", "Xayah"],
            "MinWinrate": [0.4155, 0.4656, 0.4530, 0.5180, 0.4392, 0.4284, 0.4819, 0.4085, 0.4609, 0.4272]
        },
    },
}

# Convert datasets into DataFrames
dfs = []
for equation, drafts in datasets.items():
    for draft, data in drafts.items():
        df = pd.DataFrame(data)
        df["Equation"] = equation
        df["Draft"] = draft
        dfs.append(df)
        
# Additional datasets for the remaining equations
additional_equations = {
    "Equation 2": {
        "adc vs adc": {
            "Champion": ["Aphelios", "Ashe", "Caitlyn", "Corki bot", "Ezreal", "Jhin", "Jinx", "Kai'Sa", "Kog'Maw", "Xayah"],
            "MinWinrate": [0.4414, 0.4550, 0.4558, 0.5136, 0.4373, 0.4401, 0.4896, 0.4471, 0.4824, 0.4564]
        },
        "adc vs sup": {
            "Champion": ["Aphelios", "Ashe", "Caitlyn", "Corki bot", "Ezreal", "Jhin", "Jinx", "Kai'Sa", "Kog'Maw", "Xayah"],
            "MinWinrate": [0.4263, 0.4562, 0.4558, 0.5077, 0.4373, 0.4401, 0.4863, 0.4152, 0.4602, 0.4508]
        },
        "adc 1v2": {
            "Champion": ["Aphelios", "Ashe", "Caitlyn", "Corki bot", "Ezreal", "Jhin", "Jinx", "Kai'Sa", "Kog'Maw", "Xayah"],
            "MinWinrate": [0.4341, 0.4636, 0.4558, 0.5103, 0.4373, 0.4401, 0.4863, 0.4152, 0.4602, 0.4518]
        },
    },
    "Equation 3": {
        "adc vs adc": {
            "Champion": ["Aphelios", "Ashe", "Caitlyn", "Corki bot", "Ezreal", "Jhin", "Jinx", "Kai'Sa", "Kog'Maw", "Xayah"],
            "MinWinrate": [0.4389, 0.4723, 0.4620, 0.5217, 0.4553, 0.4488, 0.4887, 0.4485, 0.4789, 0.4639]
        },
        "adc vs sup": {
            "Champion": ["Aphelios", "Ashe", "Caitlyn", "Corki bot", "Ezreal", "Jhin", "Jinx", "Kai'Sa", "Kog'Maw", "Xayah"],
            "MinWinrate": [0.4392, 0.4688, 0.4542, 0.5110, 0.4494, 0.4478, 0.4782, 0.4295, 0.4592, 0.46]
        },
        "adc 1v2": {
            "Champion": ["Aphelios", "Ashe", "Caitlyn", "Corki bot", "Ezreal", "Jhin", "Jinx", "Kai'Sa", "Kog'Maw", "Xayah"],
            "MinWinrate": [0.4421, 0.4733, 0.4542, 0.5112, 0.4553, 0.4478, 0.4782, 0.4311, 0.4592, 0.46]
        },
    },
    "Equation 4": {
        "adc vs adc": {
            "Champion": ["Aphelios", "Ashe", "Caitlyn", "Corki bot", "Ezreal", "Jhin", "Jinx", "Kai'Sa", "Kog'Maw", "Xayah"],
            "MinWinrate": [0.2955, 0.2247, 0.3393, 0.4629, 0.0919, 0.07, 0.5370, 0.1610, 0.4242, 0.2766]
        },
        "adc vs sup": {
            "Champion": ["Aphelios", "Ashe", "Caitlyn", "Corki bot", "Ezreal", "Jhin", "Jinx", "Kai'Sa", "Kog'Maw", "Xayah"],
            "MinWinrate": [0.0609, 0.2247, 0.3393, 0.4629, 0.0919, 0.07, 0.5370, 0.0992, 0.3715, 0.1259]
        },
        "adc 1v2": {
            "Champion": ["Aphelios", "Ashe", "Caitlyn", "Corki bot", "Ezreal", "Jhin", "Jinx", "Kai'Sa", "Kog'Maw", "Xayah"],
            "MinWinrate": [0.0609, 0.2247, 0.3393, 0.4629, 0.0919, 0.07, 0.5370, 0.0992, 0.3715, 0.1259]
        },
    },
    "Equation 5": {
        "adc vs adc": {
            "Champion": ["Aphelios", "Ashe", "Caitlyn", "Corki bot", "Ezreal", "Jhin", "Jinx", "Kai'Sa", "Kog'Maw", "Xayah"],
            "MinWinrate": [0.4274, 0.4426, 0.4545, 0.5115, 0.4079, 0.3977, 0.4884, 0.4119, 0.4655, 0.4502]
        },
        "adc vs sup": {
            "Champion": ["Aphelios", "Ashe", "Caitlyn", "Corki bot", "Ezreal", "Jhin", "Jinx", "Kai'Sa", "Kog'Maw", "Xayah"],
            "MinWinrate": [0.3839, 0.4426, 0.4545, 0.5115, 0.4079, 0.3977, 0.4884, 0.3780, 0.4584, 0.3979]
        },
        "adc 1v2": {
            "Champion": ["Aphelios", "Ashe", "Caitlyn", "Corki bot", "Ezreal", "Jhin", "Jinx", "Kai'Sa", "Kog'Maw", "Xayah"],
            "MinWinrate": [0.3876, 0.4426, 0.4545, 0.5115, 0.4079, 0.3977, 0.4884, 0.3780, 0.4584, 0.4050]
        },
    },
}

# Convert additional datasets into DataFrames
for equation, drafts in additional_equations.items():
    for draft, data in drafts.items():
        df = pd.DataFrame(data)
        df["Equation"] = equation
        df["Draft"] = draft
        dfs.append(df)

# Combine all datasets
df_all = pd.concat(dfs)

sns.set(style="whitegrid")

# Generate line plots for each draft type
for draft_type in df_all["Draft"].unique():
    plt.figure(figsize=(12, 6))
    subset = df_all[df_all["Draft"] == draft_type]
    sns.lineplot(data=subset, x="Champion", y="MinWinrate", hue="Equation", marker="o")

    plt.xticks(rotation=90)
    plt.xlabel("Champion")
    plt.ylabel("MinWinrate")
    plt.title(f"Winrate Trends Across Equation Variations ({draft_type})")
    plt.legend(title="Heuristic Equation")
    plt.tight_layout()
    plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Define datasets (original equation)
original_data = {
    "adc vs adc : alternative draft": {
        "Aphelios": 0.4193, "Ashe": 0.4112, "Caitlyn": 0.4419, "Corki bot": 0.5030,
        "Ezreal": 0.3564, "Jhin": 0.345, "Jinx": 0.4970, "Kai'Sa": 0.3768,
        "Kog'Maw": 0.4746, "Xayah": 0.4262
    },
    "adc vs sup : alternative draft": {
        "Aphelios": 0.3310, "Ashe": 0.4112, "Caitlyn": 0.4378, "Corki bot": 0.5030,
        "Ezreal": 0.3564, "Jhin": 0.345, "Jinx": 0.4970, "Kai'Sa": 0.3322,
        "Kog'Maw": 0.4431, "Xayah": 0.3488
    },
    "adc : 1v2 draft": {
        "Aphelios": 0.3389, "Ashe": 0.4112, "Caitlyn": 0.4378, "Corki bot": 0.5030,
        "Ezreal": 0.3564, "Jhin": 0.345, "Jinx": 0.4970, "Kai'Sa": 0.3322,
        "Kog'Maw": 0.4431, "Xayah": 0.3535
    }
}

# Equation variations
equation_data = {
    f"Equation {i}": {
        "adc vs adc : alternative draft": {
            "Aphelios": v[0], "Ashe": v[1], "Caitlyn": v[2], "Corki bot": v[3],
            "Ezreal": v[4], "Jhin": v[5], "Jinx": v[6], "Kai'Sa": v[7],
            "Kog'Maw": v[8], "Xayah": v[9]
        },
        "adc vs sup : alternative draft": {
            "Aphelios": v[10], "Ashe": v[11], "Caitlyn": v[12], "Corki bot": v[13],
            "Ezreal": v[14], "Jhin": v[15], "Jinx": v[16], "Kai'Sa": v[17],
            "Kog'Maw": v[18], "Xayah": v[19]
        },
        "adc : 1v2 draft": {
            "Aphelios": v[20], "Ashe": v[21], "Caitlyn": v[22], "Corki bot": v[23],
            "Ezreal": v[24], "Jhin": v[25], "Jinx": v[26], "Kai'Sa": v[27],
            "Kog'Maw": v[28], "Xayah": v[29]
        }
    }
    for i, v in enumerate([
        [0.4300, 0.4653, 0.4531, 0.5181, 0.4393, 0.4284, 0.4819, 0.4298, 0.4675, 0.4474, 
         0.4156, 0.4647, 0.4531, 0.5181, 0.4393, 0.4284, 0.4819, 0.4086, 0.4609, 0.4273, 
         0.4156, 0.4656, 0.4531, 0.5181, 0.4393, 0.4284, 0.4819, 0.4086, 0.4609, 0.4273],
        
        [0.4415, 0.4550, 0.4559, 0.5137, 0.4374, 0.4401, 0.4896, 0.4472, 0.4824, 0.4565, 
         0.4264, 0.4562, 0.4559, 0.5078, 0.4374, 0.4401, 0.4863, 0.4153, 0.4603, 0.4508, 
         0.4342, 0.4636, 0.4559, 0.5104, 0.4374, 0.4401, 0.4863, 0.4153, 0.4603, 0.4518],

        [0.4389, 0.4723, 0.4620, 0.5217, 0.4553, 0.4489, 0.4887, 0.4485, 0.4789, 0.4640, 
         0.4392, 0.4688, 0.4542, 0.5111, 0.4495, 0.4478, 0.4783, 0.4296, 0.4593, 0.4600, 
         0.4421, 0.4733, 0.4542, 0.5113, 0.4553, 0.4478, 0.4783, 0.4311, 0.4593, 0.4600],

        [0.2956, 0.2247, 0.3394, 0.4630, 0.0919, 0.07, 0.5370, 0.1611, 0.4243, 0.2766, 
         0.0610, 0.2247, 0.3394, 0.4630, 0.0919, 0.07, 0.5370, 0.0993, 0.3716, 0.1259, 
         0.0610, 0.2247, 0.3394, 0.4630, 0.0919, 0.07, 0.5370, 0.0993, 0.3716, 0.1259],

        [0.4275, 0.4426, 0.4545, 0.5116, 0.4079, 0.3978, 0.4884, 0.4120, 0.4656, 0.4502, 
         0.3840, 0.4426, 0.4545, 0.5116, 0.4079, 0.3978, 0.4884, 0.3781, 0.4584, 0.3980, 
         0.3877, 0.4426, 0.4545, 0.5116, 0.4079, 0.3978, 0.4884, 0.3781, 0.4584, 0.4051]
    ], start=1)
}

# Create box plots
fig, axes = plt.subplots(1, 3, figsize=(15, 5))

for ax, (dataset_name, original) in zip(axes, original_data.items()):
    data = [list(original.values())] + [
        list(equation_data[f"Equation {i}"][dataset_name].values()) for i in range(1, 6)
    ]
    ax.boxplot(data, labels=["Original"] + [f"Equation {i}" for i in range(1, 6)])
    ax.set_title(dataset_name)
    ax.set_ylabel("Win Rate")

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Define datasets (original equation)
original_data = {
    "adc vs adc : alternative draft": {
        "Aphelios": 0.4193, "Ashe": 0.4112, "Caitlyn": 0.4419, "Corki bot": 0.5030,
        "Ezreal": 0.3564, "Jhin": 0.345, "Jinx": 0.4970, "Kai'Sa": 0.3768,
        "Kog'Maw": 0.4746, "Xayah": 0.4262
    },
    "adc vs sup : alternative draft": {
        "Aphelios": 0.3310, "Ashe": 0.4112, "Caitlyn": 0.4378, "Corki bot": 0.5030,
        "Ezreal": 0.3564, "Jhin": 0.345, "Jinx": 0.4970, "Kai'Sa": 0.3322,
        "Kog'Maw": 0.4431, "Xayah": 0.3488
    },
    "adc : 1v2 draft": {
        "Aphelios": 0.3389, "Ashe": 0.4112, "Caitlyn": 0.4378, "Corki bot": 0.5030,
        "Ezreal": 0.3564, "Jhin": 0.345, "Jinx": 0.4970, "Kai'Sa": 0.3322,
        "Kog'Maw": 0.4431, "Xayah": 0.3535
    }
}

# Equation variations (without Equation 4)
equation_data = {
    f"Equation {i}": {
        "adc vs adc : alternative draft": {
            "Aphelios": v[0], "Ashe": v[1], "Caitlyn": v[2], "Corki bot": v[3],
            "Ezreal": v[4], "Jhin": v[5], "Jinx": v[6], "Kai'Sa": v[7],
            "Kog'Maw": v[8], "Xayah": v[9]
        },
        "adc vs sup : alternative draft": {
            "Aphelios": v[10], "Ashe": v[11], "Caitlyn": v[12], "Corki bot": v[13],
            "Ezreal": v[14], "Jhin": v[15], "Jinx": v[16], "Kai'Sa": v[17],
            "Kog'Maw": v[18], "Xayah": v[19]
        },
        "adc : 1v2 draft": {
            "Aphelios": v[20], "Ashe": v[21], "Caitlyn": v[22], "Corki bot": v[23],
            "Ezreal": v[24], "Jhin": v[25], "Jinx": v[26], "Kai'Sa": v[27],
            "Kog'Maw": v[28], "Xayah": v[29]
        }
    }
    for i, v in enumerate([
        [0.4300, 0.4653, 0.4531, 0.5181, 0.4393, 0.4284, 0.4819, 0.4298, 0.4675, 0.4474, 
         0.4156, 0.4647, 0.4531, 0.5181, 0.4393, 0.4284, 0.4819, 0.4086, 0.4609, 0.4273, 
         0.4156, 0.4656, 0.4531, 0.5181, 0.4393, 0.4284, 0.4819, 0.4086, 0.4609, 0.4273],
        
        [0.4415, 0.4550, 0.4559, 0.5137, 0.4374, 0.4401, 0.4896, 0.4472, 0.4824, 0.4565, 
         0.4264, 0.4562, 0.4559, 0.5078, 0.4374, 0.4401, 0.4863, 0.4153, 0.4603, 0.4508, 
         0.4342, 0.4636, 0.4559, 0.5104, 0.4374, 0.4401, 0.4863, 0.4153, 0.4603, 0.4518],

        [0.4389, 0.4723, 0.4620, 0.5217, 0.4553, 0.4489, 0.4887, 0.4485, 0.4789, 0.4640, 
         0.4392, 0.4688, 0.4542, 0.5111, 0.4495, 0.4478, 0.4783, 0.4296, 0.4593, 0.4600, 
         0.4421, 0.4733, 0.4542, 0.5113, 0.4553, 0.4478, 0.4783, 0.4311, 0.4593, 0.4600],

        [0.4275, 0.4426, 0.4545, 0.5116, 0.4079, 0.3978, 0.4884, 0.4120, 0.4656, 0.4502, 
         0.3840, 0.4426, 0.4545, 0.5116, 0.4079, 0.3978, 0.4884, 0.3781, 0.4584, 0.3980, 
         0.3877, 0.4426, 0.4545, 0.5116, 0.4079, 0.3978, 0.4884, 0.3781, 0.4584, 0.4051]
    ], start=1)
}

# Create box plots
fig, axes = plt.subplots(1, 3, figsize=(15, 5))

for ax, (dataset_name, original) in zip(axes, original_data.items()):
    data = [list(original.values())] + [
        list(equation_data[f"Equation {i}"][dataset_name].values()) for i in range(1, 5)  # Equations 1-3,5
    ]
    ax.boxplot(data, labels=["Original"] + [f"Equation {i}" for i in [1, 2, 3, 5]])  # Skipping 4
    ax.set_title(dataset_name)
    ax.set_ylabel("Win Rate")

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Data for the table
data = {
    'Variation': [1, 2, 3, 4, 5],
    'Key Change': [
        'Emphasises ADC matchups', 
        'Emphasises Support matchups', 
        'Downplays synergy', 
        'Overemphasises synergy', 
        'Balanced weighting'
    ],
    'Rationale': [
        'ADCs are seen as carry champions', 
        'Supports impact map control', 
        'Tests individual strength over team synergy', 
        'Tests impact of extreme synergy', 
        'A realistic, slightly adjusted alternative'
    ]
}

# Create the DataFrame
df = pd.DataFrame(data)

# Plot the table
fig, ax = plt.subplots(figsize=(10, 4))
ax.axis('off')
table = ax.table(cellText=df.values, colLabels=df.columns, loc='center', cellLoc='center')
table.auto_set_font_size(False)
table.set_fontsize(10)
table.scale(1.2, 1.6)

plt.tight_layout()
plt.show()
